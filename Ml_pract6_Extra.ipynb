# %% [markdown]
# <a href="https://colab.research.google.com/github/mudassirbeg/Mudassir_ML-Codes/blob/main/Ml_pract6_Extra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mudassir m Beg (CS23089)**
#
#
# Practical 6 **Extra**
#
# **AIM:-** to design and implement an Artificial Neural Network for classification problems and evaluate its learning performance.

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
path= "/content/drive/MyDrive/ML_Dataset/Heart_Failure_Prediction_dataset.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df.isnull().any().any()
# Out:
# np.False_

# %%
df[df.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df[df.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
X = df.iloc[:, 3:-1]

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
X.shape
# Out:
# (918, 8)

# %%
y=df.iloc[:,-1]
print(y)
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
X=pd.get_dummies(X, dtype = int)

# %%
X.head()
# Out:
#    RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  RestingECG_LVH  \
# 0        140          289          0    172      0.0               0
# 1        160          180          0    156      1.0               0
# 2        130          283          0     98      0.0               0
# 3        138          214          0    108      1.5               0
# 4        150          195          0    122      0.0               0
#
#    RestingECG_Normal  RestingECG_ST  ExerciseAngina_N  ExerciseAngina_Y  \
# 0                  1              0                 1                 0
# 1                  1              0                 1                 0
# 2                  0              1                 1                 0
# 3                  1              0                 0                 1
# 4                  1              0                 1                 0
#
#    ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up
# 0              0              0            1
# ...

# %%
X
# Out:
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  RestingECG_LVH  \
# 0          140          289          0    172      0.0               0
# 1          160          180          0    156      1.0               0
# 2          130          283          0     98      0.0               0
# 3          138          214          0    108      1.5               0
# 4          150          195          0    122      0.0               0
# ..         ...          ...        ...    ...      ...             ...
# 913        110          264          0    132      1.2               0
# 914        144          193          1    141      3.4               0
# 915        130          131          0    115      1.2               0
# 916        130          236          0    174      0.0               1
# 917        138          175          0    173      0.0               0
#
#      RestingECG_Normal  RestingECG_ST  ExerciseAngina_N  ExerciseAngina_Y  \
# ...

# %%
X.columns
# Out:
# Index(['RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'RestingECG_LVH', 'RestingECG_Normal', 'RestingECG_ST',
#        'ExerciseAngina_N', 'ExerciseAngina_Y', 'ST_Slope_Down',
#        'ST_Slope_Flat', 'ST_Slope_Up'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state = 42)
X_train.shape, X_test.shape
# Out:
# ((642, 13), (276, 13))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-1.77231378,  0.2949892 , -0.52568236, ..., -0.25431598,
#         -1.02524056,  1.15890711],
#        [-1.23486848, -1.90539005,  1.90228942, ...,  3.93211628,
#         -1.02524056, -0.86288193],
#        [ 1.45235803, -1.90539005,  1.90228942, ..., -0.25431598,
#          0.97538084, -0.86288193],
#        ...,
#        [-0.15997788,  0.47365248, -0.52568236, ..., -0.25431598,
#         -1.02524056,  1.15890711],
#        [ 1.02240179, -1.90539005, -0.52568236, ..., -0.25431598,
#         -1.02524056,  1.15890711],
#        [ 0.91491273,  1.78071537, -0.52568236, ..., -0.25431598,
#          0.97538084, -0.86288193]])

# %%
X_test
# Out:
# array([[ 0.37746742, -0.07174067, -0.52568236, ..., -0.25431598,
#         -1.02524056,  1.15890711],
#        [ 0.64619008,  2.96553496, -0.52568236, ..., -0.25431598,
#          0.97538084, -0.86288193],
#        [ 1.45235803, -1.90539005,  1.90228942, ..., -0.25431598,
#          0.97538084, -0.86288193],
#        ...,
#        [-0.15997788,  0.75575238,  1.90228942, ...,  3.93211628,
#         -1.02524056, -0.86288193],
#        [ 1.45235803, -1.90539005, -0.52568236, ..., -0.25431598,
#          0.97538084, -0.86288193],
#        [-0.69742318,  1.2917422 , -0.52568236, ..., -0.25431598,
#         -1.02524056,  1.15890711]])

# %% [markdown]
# Tensor as tf

# %%
ann = tf.keras.models.Sequential()

# %%
#Creating Hidden Layers
#Adding 1 Hidden Layers
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
#Adding 2 Hidden Layers
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
#Output Layer
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
#compiling the ANN
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
ann.fit(X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6433 - loss: 0.6628
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7287 - loss: 0.6382
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7605 - loss: 0.6094
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7721 - loss: 0.5755
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7840 - loss: 0.5465
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7728 - loss: 0.5355
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7548 - loss: 0.5307
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7901 - loss: 0.4880
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8154 - loss: 0.4909
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8078 - loss: 0.4762
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8199 - loss: 0.4418
# Epoch 12/100
# ...

# %%
#prediction the test set rules
y_pred = ann.predict(X_test)
y_pred = (y_pred > 0.5)
y_pred
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# array([[False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
# ...

# %%
from sklearn.metrics import confusion_matrix
print('Confusion Matrix')
cm = confusion_matrix(y_pred,y_test)
print(confusion_matrix(y_pred,y_test))
# Out:
# Confusion Matrix
# [[ 89  22]
#  [ 23 142]]

# %%
print('Accuracy Score')
print(accuracy_score(y_pred,y_test))
# Out:
# Accuracy Score
# 0.8369565217391305

# %%
from sklearn.metrics import classification_report
print('Classification Report')
print(classification_report(y_pred,y_test))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#        False       0.79      0.80      0.80       111
#         True       0.87      0.86      0.86       165
#
#     accuracy                           0.84       276
#    macro avg       0.83      0.83      0.83       276
# weighted avg       0.84      0.84      0.84       276
