# %% [markdown]
# <a href="https://colab.research.google.com/github/mudassirbeg/Mudassir_ML-Codes/blob/main/ML_pract3_Extra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mudassir M Beg****CS23089**
#
# Aim 3_Extra:To implement Logistic Regression for binary or multiclass classification problems and analyze the classification performance.

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/ML_Dataset/diabetes_prediction_dataset.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
df.shape
# Out:
# (100000, 9)

# %%
df['smoking_history'].unique()
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df = df[df['smoking_history'] != 'never']

# %%
df.head()
# Out:
#     gender   age  hypertension  heart_disease smoking_history    bmi  \
# 1   Female  54.0             0              0         No Info  27.32
# 3   Female  36.0             0              0         current  23.45
# 4     Male  76.0             1              1         current  20.14
# 7   Female  79.0             0              0         No Info  23.86
# 11  Female  54.0             0              0          former  54.70
#
#     HbA1c_level  blood_glucose_level  diabetes
# 1           6.6                   80         0
# 3           5.0                  155         0
# 4           4.8                  155         0
# 7           5.7                   85         0
# 11          6.0                  100         0

# %%
df.shape
# Out:
# (64905, 9)

# %%
df['smoking_history'] = df['smoking_history'].map({
    'not current':0,
    'ever':1,
    'No Info':2,
    'current':3,
    'former':4
})

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

print(X)
print(y)
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 1      Female  54.0             0              0                2  27.32
# 3      Female  36.0             0              0                3  23.45
# 4        Male  76.0             1              1                3  20.14
# 7      Female  79.0             0              0                2  23.86
# 11     Female  54.0             0              0                4  54.70
# ...       ...   ...           ...            ...              ...    ...
# 99994  Female  36.0             0              0                2  24.60
# 99995  Female  80.0             0              0                2  27.32
# 99996  Female   2.0             0              0                2  17.37
# 99997    Male  66.0             0              0                4  27.83
# 99999  Female  57.0             0              0                3  22.43
#
#        HbA1c_level  blood_glucose_level
# 1              6.6                   80
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    train_size=0.7,
    test_size=0.3,
    random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
X_train_processed = pd.get_dummies(
    X_train,
    columns=['gender','smoking_history'],
    drop_first=True
)

X_test_processed = pd.get_dummies(
    X_test,
    columns=['gender','smoking_history'],
    drop_first=True
)

# %%
X_test_processed = X_test_processed.reindex(
    columns=X_train_processed.columns,
    fill_value=0
)

# %%
classifier.fit(X_train_processed, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = classifier.predict(X_test_processed)

# %%
score = accuracy_score(y_test, y_pred)
print(score)
# Out:
# 0.9572719802793755

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     18001
#            1       0.80      0.58      0.67      1471
#
#     accuracy                           0.96     19472
#    macro avg       0.88      0.78      0.82     19472
# weighted avg       0.95      0.96      0.95     19472

# %%
sns.pairplot(df, hue='smoking_history')
